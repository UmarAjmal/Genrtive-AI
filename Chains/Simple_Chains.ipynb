# %%
# %pip install grandalf
from langchain_huggingface import ChatHuggingFace, HuggingFaceEndpoint
from langchain_core.prompts import PromptTemplate
from langchain_core.output_parsers import StrOutputParser
from dotenv import load_dotenv
import os

# Step 1: Load API key from .env file
load_dotenv()
api_key = os.getenv("HUGGINGFACE_API_KEY")

# Step 2: Select a parser for the output (in this case, a simple string parser)
str_parser = StrOutputParser()

# Step 3: Initialize the HuggingFaceEndpoint with the desired model and task
llm = HuggingFaceEndpoint(
    repo_id="meta-llama/Llama-3.1-8B-Instruct",
    task="text-generation",
    huggingfacehub_api_token=api_key
)

# Step 4: Create a prompt template to generate interesting facts about a given topic
prompt = PromptTemplate( template="Generate 5 interesting facts releated to {topic}.",  input_variables=["topic"] )

# Step 5: Initialize the ChatHuggingFace model with the HuggingFaceEndpoint
model = ChatHuggingFace(llm=llm)

# Step 6: Chain the prompt, model, and output parser together
chain = (
    prompt
    | model 
    | str_parser
)

# Step 7: Invoke the chain with a specific topic and print the results
result =chain.invoke({"topic": "Black Holes"})

# Step 8: Print the result
print(result)

chain.get_graph().print_ascii()
# Out:
# Here are five interesting facts related to Black Holes:
#
# 1. **The Tidal Forces are so Strong that they can Rip Stars Apart**: If you were to get too close to a black hole, the tidal forces would stretch you apart at the molecular level, a process known as spaghettification. This is because the gravity near a black hole is so strong that it would cause objects to be pulled apart at different rates, depending on their distance from the center of the black hole.
#
# 2. **The Event Horizon is not a Physical Boundary, but a Point of No Return**: The event horizon is the point of no return around a black hole, marking the boundary beyond which nothing, not even light, can escape the black hole's gravity. However, it is not a physical boundary, but rather a mathematical concept. Once you cross the event horizon, you are trapped by the black hole's gravity and cannot escape.
#
# 3. **Black Holes Come in Different Sizes, from Small to Supermassive**: While most people think of black holes as massive objects with huge event horizons, there are also small, stellar-mass black holes that form from the collapse of individual stars. Supermassive black holes, on the other hand, are found at the centers of galaxies and can have masses millions or even billions of times that of the sun.
#
# 4. **If you Were to Fall into a Black Hole, Time Would Appear to Slow Down for You Relative to Outside Observers**: According to Einstein's theory of general relativity, time dilation occurs near a black hole due to the intense gravitational field. If you were to fall into a black hole, time would appear to slow down for you relative to outside observers, who would see time passing normally. This effect becomes more pronounced as you approach the event horizon.
#
# 5. **Black Holes can be 'Hearing' the Cosmic Microwave Background Radiation**: The cosmic microwave background radiation (CMB) is the residual heat from the Big Bang, which fills the universe. Researchers have found that black holes can be 'hearing' the CMB radiation, which is thought to be a signature of the early universe. This radiation can be detected in the form of Hawking radiation, a theoretical prediction that black holes emit radiation due to quantum effects near the event horizon.
#
# These facts show just how fascinating and complex black holes are, and there is still much to be learned about these mysterious objects in our universe.
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[10], line 41
#      38 # Step 8: Print the result
#      39 print(result)
# ---> 41 chain.get_graph().print_ascii()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\langchain_core\runnables\graph.py:523, in Graph.print_ascii(self)
#     521 def print_ascii(self) -> None:
#     522     """Print the graph as an ASCII art string."""
# --> 523     print(self.draw_ascii())
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\langchain_core\runnables\graph.py:516, in Graph.draw_ascii(self)
#     513 # Import locally to prevent circular import
#     514 from langchain_core.runnables.graph_ascii import draw_ascii  # noqa: PLC0415
# --> 516 return draw_ascii(
#     517     {node.id: node.name for node in self.nodes.values()},
#     518     self.edges,
#     519 )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\langchain_core\runnables\graph_ascii.py:299, in draw_ascii(vertices, edges)
#     296 xlist: list[float] = []
#     297 ylist: list[float] = []
# --> 299 sug = _build_sugiyama_layout(vertices, edges)
#     301 for vertex in sug.g.sV:
#     302     # NOTE: moving boxes w/2 to the left
#     303     xlist.extend(
#     304         (
#     305             vertex.view.xy[0] - vertex.view.w / 2.0,
#     306             vertex.view.xy[0] + vertex.view.w / 2.0,
#     307         )
#     308     )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\langchain_core\runnables\graph_ascii.py:206, in _build_sugiyama_layout(vertices, edges)
#     204 if not _HAS_GRANDALF:
#     205     msg = "Install grandalf to draw graphs: `pip install grandalf`."
# --> 206     raise ImportError(msg)
#     208 #
#     209 # Just a reminder about naming conventions:
#     210 # +------------X
#    (...)    215 # Y
#     216 #
#     218 vertices_ = {id_: Vertex(f" {data} ") for id_, data in vertices.items()}
#
# ImportError: Install grandalf to draw graphs: `pip install grandalf`.
