# %%
from langchain_community.document_loaders import DirectoryLoader, PyPDFLoader
from langchain_huggingface import ChatHuggingFace, HuggingFaceEndpoint
from langchain_core.output_parsers import StrOutputParser
from langchain_core.prompts import PromptTemplate
from dotenv import load_dotenv
import os

load_dotenv()
api_key_01 = os.getenv("HUGGINGFACE_API_KEY")

llm =  HuggingFaceEndpoint(
    repo_id="meta-llama/Llama-3.1-8B-Instruct",
    task="text-generation",
    huggingfacehub_api_token=api_key_01,
)

model = ChatHuggingFace(llm=llm)

str_parser = StrOutputParser()

directory = DirectoryLoader(path="book", glob="*.pdf", loader_cls=PyPDFLoader)

doc = directory.load()
# Out:
# 14
# MUHAMMAD UMAR AJMAL
# Vehari, Punjab, Pakistan | +92-305-901-7768 | umarajmaldeveloper@gmail.com
# LinkedIn: www.linkedin.com/in/muhammad-umar-ajmal-developer  GitHub:
# https://github.com/UmarAjmal
# SUMMARY
#
# • 1+ year of working with small, cross-functional teams and delivered projects on time and within
# scope.
# • Proficient in Agile / Scrum ceremonies, risk logs, and status-report writing.
# • Strong communicator who translates technical details into clear, actionable milestones for
# non-technical stakeholders.
#
# TECHNICAL & PRIMARY SKILLS
#
# • Requirements Gathering  • MS Office (basic) • Risk & Issue Tracking
# • Stakeholder Communication • Change Requests • Flutter • Python • MySQL • Firebase • GetX
#
# Experience
#
# WeConnect  (Flutter Intern Apr 2024)
# •  Coordinated 4 mobile-app releases; built project schedules, set sprint goals, and
# achieved 100 % on-time delivery.
# • Prepared status reports and risk registers for senior management, improving
# ...

# %%
prompt_01 = PromptTemplate(
    input_variables=["topic"],
    template="Write a summary report on the following topic: {topic}",)

chain = prompt_01 | model | str_parser

result = chain.invoke(prompt_01.format(topic=doc))

print(result)
# Out:
# **Summary Report: School Management System (SMS)**
#
# **Introduction:**
#
# The School Management System (SMS) is a proposed project aimed at automating and streamlining core administrative tasks for schools, including student admissions, attendance tracking, fee management, class scheduling, examination management, and result processing. The system is designed to improve efficiency, reduce errors, and enhance user experience for parents and administrators.
#
# **Key Features:**
#
# 1. **FamilyID Feature**: A unique system to group siblings under a single account, simplifying fee tracking and management for families and administrators.
# 2. **Admissions Module**: Manages student admission process with online forms and admin review.
# 3. **Attendance Module**: Allows teachers to mark daily attendance and generate reports.
# 4. **Scheduling Module**: Facilitates creation and viewing of class timetables.
# ...
