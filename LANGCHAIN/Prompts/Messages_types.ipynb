# %%
from langchain_core.messages import SystemMessage, HumanMessage, AIMessage
from langchain_google_genai import ChatGoogleGenerativeAI
from dotenv import load_dotenv

load_dotenv()
model = ChatGoogleGenerativeAI(model="gemini-2.5-flash", temperature=0.7)

messages = [
    SystemMessage(content="You are a helpful assistant that summarizes research papers."),
    HumanMessage(content="Summarize the paper 'Attention Is All You Need' in a concise manner.")
]

results = model.invoke(messages)
messages.append(AIMessage(content=results.content))
print(messages)
# Out:
# [SystemMessage(content='You are a helpful assistant that summarizes research papers.', additional_kwargs={}, response_metadata={}), HumanMessage(content="Summarize the paper 'Attention Is All You Need' in a concise manner.", additional_kwargs={}, response_metadata={}), AIMessage(content="The paper 'Attention Is All You Need' introduced the **Transformer** architecture, a novel neural network model that **relies solely on attention mechanisms**, eschewing recurrent (RNNs) and convolutional (CNNs) layers entirely.\n\nIts core innovation is **Self-Attention** and **Multi-Head Attention**, which allow the model to weigh the importance of different parts of the input sequence when processing each element, thereby drawing global dependencies regardless of distance. To maintain sequence order in the absence of recurrence, **Positional Encoding** is added to the input embeddings.\n\nThis design enables **significantly faster training** due to its parallelizable nature and superior ability to
# ...
