# %%
from langchain_huggingface import ChatHuggingFace, HuggingFaceEndpoint
from dotenv import load_dotenv
import os


# Get HuggingFace token
load_dotenv()
hf_token = os.getenv("HUGGINGFACE_API_KEY")


llm = HuggingFaceEndpoint(
    repo_id="meta-llama/Llama-3.1-8B-Instruct",
    task="text-generation",
    huggingfacehub_api_token=hf_token
)

model = ChatHuggingFace(llm=llm)

result = model.invoke("What is life?")
print(result.content)
# Out:
# The question of what life is, is a complex and multifaceted one that has puzzled philosophers, scientists, and thinkers for centuries. While there is no single, definitive answer, I'll attempt to provide a comprehensive overview.
#
# **Biological Perspective**
#
# From a biological standpoint, life is typically defined as the presence of certain characteristics that distinguish living organisms from non-living matter. These characteristics include:
#
# 1. **Organization**: Living organisms are composed of cells, which are the basic structural and functional units of life.
# 2. **Metabolism**: Living organisms carry out chemical reactions to sustain themselves, including growth, reproduction, and response to their environment.
# 3. **Homeostasis**: Living organisms maintain a stable internal environment despite changes in the external environment.
# 4. **Growth and Development**: Living organisms grow and develop over time, often through a series of stages.
# 5. **Reproduction**: Living organisms produce offspring to ensure the continuation of their genetic material.
# 6. **Response to Stimuli**: Living organisms can respond to their environment, either through instinct or learning.
# 7. **Evolution**: Living organisms can evolve over time through the process of natural selection.
#
# **Philosophical Perspective**
#
# From a philosophical standpoint, life can be seen as more complex and multifaceted. Some philosophers have suggested that life encompasses not only biological characteristics but also:
#
# 1. **Consciousness**: The ability to experience and perceive the world around us.
# 2. **Cognition**: The ability to think, reason, and learn.
# 3. **Emotions**: The ability to experience emotions and develop relationships.
# 4. **Values and Meaning**: The ability to assign meaning and value to life, and to create purpose and direction.
#
# **Other Perspectives**
#
# Other perspectives on life include:
#
# 1. **Spiritual**: Many spiritual traditions believe that life is a spiritual journey, guided by a higher power or a sense of connection to the universe.
# 2. **Existential**: Existentialists believe that life is inherently meaningless, and that we must create our own purpose and meaning in life.
# 3. **Quantum**: Some theories in physics suggest that life is a fundamental aspect of the universe, and that consciousness may be a product of quantum processes.
#
# In conclusion, while there is no single definition of life, it is clear that it encompasses a wide range of characteristics, from the biological to the philosophical, and beyond.
