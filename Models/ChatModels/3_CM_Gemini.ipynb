# %%
from langchain_google_genai import ChatGoogleGenerativeAI
from dotenv import load_dotenv
import os

load_dotenv()


model = ChatGoogleGenerativeAI(model="gemini-2.5-flash")
result = model.invoke("What is the meaning of life?")
print(result.content)
# Out:
# That's one of the most profound and enduring questions humanity has ever asked, and there isn't a single, universally agreed-upon answer. Different philosophies, religions, and individuals offer a wide range of perspectives:
#
# 1.  **No Inherent Meaning (Existentialism):** Many philosophers, particularly those in the existentialist tradition (like Sartre or Camus), argue that life has no inherent, pre-ordained meaning. From this perspective, the universe is indifferent, and it's up to each individual to create their own meaning through their choices, actions, and values. We are condemned to be free, and we define our own purpose.
#
# 2.  **Religious/Spiritual Meaning:** For billions of people, meaning is found in religious or spiritual beliefs. This often involves:
#     *   **Divine Purpose:** Life is a gift from a creator, and its meaning is tied to fulfilling a divine plan, serving a higher power, or achieving salvation/enlightenment.
#     *   **Afterlife/Karma:** Meaning is related to actions in this life determining one's fate in an afterlife or future reincarnation.
#     *   **Moral Code:** Following specific ethical guidelines and commandments is central to a meaningful life.
#
# 3.  **Humanistic/Secular Meaning:** Many who don't subscribe to religious views find meaning in humanistic values and experiences. This can include:
#     *   **Love and Connection:** Deep relationships with others, family, and community.
#     *   **Contribution and Altruism:** Making a positive difference in the world, helping others, or leaving a legacy.
#     *   **Creativity and Self-Expression:** Art, music, writing, innovation, and expressing one's unique perspective.
#     *   **Learning and Growth:** Seeking knowledge, understanding the world, and personal development.
#     *   **Pursuit of Happiness/Well-being:** Finding joy, contentment, and fulfillment in life's experiences.
#     *   **Experiencing Beauty:** Appreciating nature, art, and the richness of existence.
#
# 4.  **Biological/Evolutionary Meaning:** From a purely biological perspective, life's "purpose" might be seen as survival and reproduction – ensuring the continuation of the species. However, this doesn't fully capture the richness of human experience and our quest for deeper significance beyond basic biological drives.
#
# **Perhaps the most common contemporary understanding is that the meaning of life is not something you discover, but something you create.**
#
# It's a deeply personal and subjective quest. What brings meaning to one person's life might be completely different for another. It can evolve over time, change with experiences, and be found in grand gestures or quiet moments, in service to others or in personal fulfillment.
#
# Ultimately, the "meaning of life" is what you define it to be through how you live, what you value, and what you choose to dedicate your energy to.
