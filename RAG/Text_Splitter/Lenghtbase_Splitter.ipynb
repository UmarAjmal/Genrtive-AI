# %%
from langchain_text_splitters import CharacterTextSplitter
from langchain_community.document_loaders import PyPDFLoader

loader = PyPDFLoader("sample.pdf")

data = loader.load()

splitter = CharacterTextSplitter(chunk_size=10, chunk_overlap=0)

chunk = splitter.split_documents(data)

print(chunk)
# Out:
# [Document(metadata={'producer': 'Microsoft® Word for Microsoft 365', 'creator': 'Microsoft® Word for Microsoft 365', 'creationdate': '2025-04-22T08:52:12+05:00', 'moddate': '2025-04-22T08:52:12+05:00', 'source': 'sample.pdf', 'total_pages': 1, 'page': 0, 'page_label': '1'}, page_content='MUHAMMAD UMAR AJMAL \nVehari, Punjab, Pakistan | +92-305-901-7768 | umarajmaldeveloper@gmail.com \nLinkedIn: www.linkedin.com/in/muhammad-umar-ajmal-developer  GitHub: \nhttps://github.com/UmarAjmal \nSUMMARY  \n \n• 1+ year of working with small, cross-functional teams and delivered projects on time and within \nscope. \n• Proficient in Agile / Scrum ceremonies, risk logs, and status-report writing. \n• Strong communicator who translates technical details into clear, actionable milestones for \nnon-technical stakeholders. \n \nTECHNICAL & PRIMARY SKILLS\n \n• Requirements Gathering  • MS\u202fOffice (basic) • Risk & Issue Tracking  \n• Stakeholder Communication • Change Requests • Flutter • Python • MySQL • Firebase • GetX  \n \nExperience \n \nWeConnect  (Flutter Intern Apr\u202f2024) \n•  Coordinated 4 mobile-app releases; built project schedules, set sprint goals, and   \nachieved 100\u202f% on-time delivery. \n• Prepared status reports and risk registers for senior management, improving \ndecision-making speed. \n•  Assisted with full SDLC: requirement elicitation → UI/UX mock-ups → UAT sign-off. \n \nRELEVANT PROJECTS\n \n1. Task Manager (Python Desktop): Plane and schedule tasks; multithreaded PYQT GUI.  \n2. POS System Software (Python, MySQL)\u202f: Built backlog & database; cut feature creep 15\u202f%; \nhandles. \n3. School System Software (Python, MySQL): Streamline the process of admissions, attendance, \nmonthly fee management and much more. \n4. Teacher-Student App (Flutter, Firebase): Capstone; managed scheduling & progress tracking; \nmitigated sync-latency risk.  \n5. Medical History Tracking App (Flutter, Firebase): Personal project that store medical history of \nfamily. \n \nEDUCATION  \n \nBachelor of Science in Computer Science (BSCS) — COMSATS University, Islamabad \nExpected Graduation: 2026 \n \nCERTIFICATIONS & TRAINING \n \n• Flutter App Development (2024)')]
